# %%
# %matplotlib inline
from chainercv.datasets import TransformDataset
from chainercv import transforms
import chainer

# Load the MNIST dataset
def transform(in_data):
    img, label = in_data
    img = transforms.random_expand(img, max_ratio=3)
    img = transforms.resize(img, (28, 28))
    return img, label
train, test = chainer.datasets.get_mnist(ndim=3)
train = TransformDataset(train, transform)
test = TransformDataset(test, transform)

# %%
for i in range(10):
    img, label = train[i]
    img_vis = transforms.chw_to_pil_image(img * 255)[:, :, 0]
    plt.imshow(img_vis, cmap='gray', interpolation='nearest')
    print label
    plt.show()
# Out:
# 5
# 0
# 4
# 1
# 9
# 2
# 1
# 3
# 1
# 4
