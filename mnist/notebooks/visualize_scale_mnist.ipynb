# %%
# %matplotlib inline
from chainercv.datasets import TransformDataset
from chainercv import transforms
import chainer

# Load the MNIST dataset
def transform(in_data):
    img, label = in_data
    img = transforms.random_expand(img, max_ratio=3)
    img = transforms.resize(img, (28, 28))
    return img, label
raw_train, test = chainer.datasets.get_mnist(ndim=3)
train = TransformDataset(raw_train, transform)
test = TransformDataset(test, transform)

# %%
for i in range(10):
    img, label = train[i]
    raw_img, _ = raw_train[i]
    img = (img * 255)[0]
    raw_img = (raw_img * 255)[0]
    fig = plt.figure()
    ax1 = fig.add_subplot(1, 2, 1)
    plt.axis('off')
    ax1.imshow(raw_img, cmap='gray', interpolation='nearest')
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img, cmap='gray', interpolation='nearest')
    plt.axis('off')
    plt.show()
